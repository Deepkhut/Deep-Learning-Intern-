# %%
pip install pillow
# Out:
# ...
#      ---------------------------------------- 2.5/2.5 MB 13.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install colorthief
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fill-voids
# Out:
# ...
#      -------------------------------------- 178.8/178.8 kB 3.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 507.8/507.8 kB 6.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip  install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 8.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 163.0/163.0 kB 4.8 MB/s eta 0:00:00
# ...
#      ------------------------------------- 965.4/965.4 kB 12.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 98.3/98.3 kB 629.3 kB/s eta 0:00:00
# ...
#      -------------------------------------- 55.4/55.4 kB 960.5 kB/s eta 0:00:00
# ...
#      --------------------------------------- 14.9/14.9 MB 14.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fast-reflection-removal
# Out:
# ...
#      ---------------------------------------- 42.2/42.2 MB 2.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # for one photo cropping

# %%
import json                                                         # this module is used to read json files
import os 
from PIL import Image
import matplotlib.pyplot as plt 
import numpy as np
import cv2

# %%
from PIL import Image
import os.path, sys
import matplotlib.pyplot as plt
Image1 = Image.open('C:/Users/Jekson/Desktop/yolo _ g_data/2/Image63.bmp')
croppedIm = Image1.crop((60,60,1100 ,570))
# croppedIm.save( 'D:/To_Do/yoloBox_data_ROI/Cropped.bmp', "BMP", quality=100)
# show the image
plt.imshow(croppedIm)

# %% [markdown]
# # for whole folder cropping

# %%
from PIL import Image
import os.path, sys

path = "C:/Users/Jekson/Desktop/yolo _ g_data/2/"
dirs = os.listdir(path)

for item in dirs:
    if os.path.isfile(path+item):
        im = Image.open(path+item)
        f, e = os.path.splitext(path+item)
        imCrop = im.crop((60,60,1100 ,570))
        imCrop.save(f+'.bmp')

# %%
from PIL import Image
import matplotlib.pyplot as plt 
 
img = Image.open('D:/test 2/photo/Image86.bmp')
 
# flip anti-clockwise
flip_img = img.transpose(Image.FLIP_LEFT_RIGHT)
 
plt.imshow(img)

flip_img.save('D:/test 2/photo/Image86.bmp')

# %%
plt.imshow(flip_img)

# %%
import json                                                         # this module is used to read json files
import os 
folder_path = "D:/test/json/"             # you specifie the folder conatining your json files

files = os.listdir(folder_path)                                     # you all the files names in the specified folder

for index,file in enumerate(files):                                 # for each file in the folder
    with open(f"{folder_path}/{file}", "r+") as f:                  # you open the file
        data = json.load(f)
        n = len(data['shapes']) #variable is set to the value of number of capsules
        coordinates=[]     #array for all the coordinates
        k=[]
        a=data['imageHeight']
        b=data['imageWidth']
         
        for i in range(0,n):
            k.append(len(data['shapes'][i]['points']))
            for j in range(0,k[i]):
                data['shapes'][i]['points'][j][1] = (resize_list[4]/100)*data['shapes'][i]['points'][j][1]       #loading one group's coordinates one by one 
                data['shapes'][i]['points'][j][0] = (resize_list[4]/100)*data['shapes'][i]['points'][j][0]
    
        data['imageHeight'] = int((resize_list[4]/100)*a)
        data['imageWidth'] = int((resize_list[4]/100)*b)
        f.seek(0)
        json.dump(data,f,indent=4)
        f.truncate()

# %%
import json                                                         # this module is used to read json files
import os 
# a= str(null)
folder_path = "D:/flip/json/" 
files = os.listdir(folder_path) 
for index,file in enumerate(files):                                 # for each file in the folder
    with open(f"{folder_path}/{file}", "r+") as f:                  # you open the file
        data = json.load(f)
        n = len(data['shapes'])
        coordinates=[]     #array for all the coordinates
        k=[]
        a=data['imageHeight']
        b=data['imageWidth']
        
        print(a,b)
        
        for i in range(0,n):
            k.append(len(data['shapes'][i]['points']))
            for j in range(0,k[i]):
#                 print(data['shapes'][i]['points'][j][0])
#                 print( data['shapes'][i]['points'][j][1])
#                 data['shapes'][i]['points'][j][1] = a - data['shapes'][i]['points'][j][1]       #loading one group's coordinates one by one 
                data['shapes'][i]['points'][j][0] = b - data['shapes'][i]['points'][j][0]
        
        
        data['imageData'] = None
       
        f.seek(0)
        json.dump(data,f,indent=4)
        f.truncate()
# Out:
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 730
# 350 730
# 350 730
# 350 730
# 350 730
# 350 730
# 350 730
# 350 730
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830
# 350 830

# %%
a= str('null')

# %%
print(a)
# Out:
# null

# %% [markdown]
# # flip image coordinates and renaming

# %%
import json                                                         # this module is used to read json files
import os 
from PIL import Image
import matplotlib.pyplot as plt 
path = "D:/test/New folder/New folder/"
dirs = os.listdir(path)

for item in dirs:
    if os.path.isfile(path+item):
        img = Image.open(path+item)
        f, e = os.path.splitext(path+item)
        flip_img = img.transpose(Image.FLIP_LEFT_RIGHT)
        flip_img.save(f+'_flip'+'.bmp')

# %%
import json                                                         # this module is used to read json files
import os 
# a= str(null)
folder_path = "D:/flip/json/" 
files = os.listdir(folder_path) 
for index,file in enumerate(files):                                 # for each file in the folder
    with open(f"{folder_path}/{file}", "r+") as f:                  # you open the file
        data = json.load(f)
        print(data['imagePath'])
        b=data['imagePath']
        c=b.split('.')[0]
        data['imagePath'] =
# Out:
# Image106.bmp
# Image107.bmp
# Image112.bmp
# Image113.bmp
# Image129.bmp
# Image130.bmp
# Image139.bmp
# Image140.bmp
# Image141.bmp
# Image162.bmp
# Image163.bmp
# Image164.bmp
# Image165.bmp
# Image230.bmp
# Image231.bmp
# Image232.bmp
# Image233.bmp
# Image244.bmp
# Image245.bmp
# Image246.bmp
# Image247.bmp
# Image270.bmp
# Image271.bmp
# Image272.bmp
# Image273.bmp
# Image298.bmp
# Image299.bmp
# Image300.bmp
# Image301.bmp
# Image319.bmp
# Image320.bmp
# Image321.bmp
# Image322.bmp
# Image337.bmp
# Image338.bmp
# Image339.bmp
# Image340.bmp
# Image369.bmp
# Image370.bmp
# Image371.bmp
# Image372.bmp
# Image373.bmp
# Image80.bmp
# Image81.bmp
# Image86.bmp
# Image87.bmp

# %%
import os
path = 'D:/flip/json'
files = os.listdir(path)


for index, file in enumerate(files):
   
    a = file.split('.')[0]
    print(a)
    os.rename(os.path.join(path, file), os.path.join(path, ''.join([a,'_flip', '.json'])))
# Out:
# Image106
# Image107
# Image112
# Image113
# Image129
# Image130
# Image139
# Image140
# Image141
# Image162
# Image163
# Image164
# Image165
# Image230
# Image231
# Image232
# Image233
# Image244
# Image245
# Image246
# Image247
# Image270
# Image271
# Image272
# Image273
# Image298
# Image299
# Image300
# Image301
# Image319
# Image320
# Image321
# Image322
# Image337
# Image338
# Image339
# Image340
# Image369
# Image370
# Image371
# Image372
# Image373
# Image80
# Image81
# Image86
# Image87

# %%
import random
import cv2
  
def add_noise(img):
  
    # Getting the dimensions of the image
    row , col = img.shape
      
    # Randomly pick some pixels in the
    # image for coloring them white
    # Pick a random number between 300 and 10000
    number_of_pixels = random.randint(300, 10000)
    for i in range(number_of_pixels):
        
        # Pick a random y coordinate
        y_coord=random.randint(0, row - 1)
          
        # Pick a random x coordinate
        x_coord=random.randint(0, col - 1)
          
        # Color that pixel to white
        img[y_coord][x_coord] = 255
          
    # Randomly pick some pixels in
    # the image for coloring them black
    # Pick a random number between 300 and 10000
    number_of_pixels = random.randint(300 , 10000)
    for i in range(number_of_pixels):
        
        # Pick a random y coordinate
        y_coord=random.randint(0, row - 1)
          
        # Pick a random x coordinate
        x_coord=random.randint(0, col - 1)
          
        # Color that pixel to black
        img[y_coord][x_coord] = 0
          
    return img
  
# salt-and-pepper noise can
# be applied only to grayscale images
# Reading the color image in grayscale image
img = cv2.imread('D:/Granules_angle_pvc_2_ROI/2/1200/both/Image162.bmp')
  
#Storing the image
cv2.imwrite('D:/test/salt-and-pepper.bmp',add_noise(img))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 47
#      44 img = cv2.imread('D:/Granules_angle_pvc_2_ROI/2/1200/both/Image162.bmp')
#      46 #Storing the image
# ---> 47 cv2.imwrite('D:/test/salt-and-pepper.bmp',add_noise(img))
#
# Cell In[4], line 7, in add_noise(img)
#       4 def add_noise(img):
#       5
#       6     # Getting the dimensions of the image
# ----> 7     row , col = img.shape
#       9     # Randomly pick some pixels in the
#      10     # image for coloring them white
#      11     # Pick a random number between 300 and 10000
#      12     number_of_pixels = random.randint(300, 10000)
#
# ValueError: too many values to unpack (expected 2)

# %%
from PIL import Image, ImageFilter 
     
# creating a image object 
im1 = Image.open(r"D:/test/blackspot.bmp") 
     
# applying the median filter 
im2 = im1.filter(ImageFilter.MedianFilter(size = 7)) 

plt.imshow(im2,cmap='gray')

# %%
input_image = Image.open('D:/test/blackspot.bmp')
gray = cv2.imread('D:/test/blackspot.bmp', 0)
# threshold
th, threshed = cv2.threshold(gray, 100, 255,cv2.THRESH_BINARY_INV|cv2.THRESH_OTSU)
# findcontours
cnts = cv2.findContours(threshed, cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2]
# filter by area
s1 = 3
s2 = 20
xcnts = []
for cnt in cnts:
    if s1<cv2.contourArea(cnt) <s2:
        xcnts.append(cnt)
print("\nDots number: {}".format(len(xcnts)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 input_image = Image.open('D:/test/blackspot.bmp')
# ----> 2 gray = cv2.imread('D:/test/blackspot.bmp', 0)
#       3 # threshold
#       4 th, threshed = cv2.threshold(gray, 100, 255,cv2.THRESH_BINARY_INV|cv2.THRESH_OTSU)
#
# NameError: name 'cv2' is not defined

# %%
import fill_voids
gray = cv2.imread('D:/test/blackspot.bmp')
th, threshed = cv2.threshold(gray, 0, 255,cv2.THRESH_BINARY_INV)
plt.imshow(threshed)
#img = threshed # 2d or 3d binary image 
#filled_image = fill_voids.fill(img, in_place=True) # in_place allows editing of original image
#filled_image, N = fill_voids.fill(img, return_fill_count=False) # returns number of voxels filled in

# %%
#plt.imshow(filled_image)

# %%
import cv2
import numpy as np

img = cv2.imread('D:/test/blackspot.bmp')
img_bw = 255*(cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) > 5).astype('uint8')

se1 = cv2.getStructuringElement(cv2.MORPH_RECT, (5,5))
se2 = cv2.getStructuringElement(cv2.MORPH_RECT, (2,2))
mask = cv2.morphologyEx(img_bw, cv2.MORPH_CLOSE, se1)
mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, se2)

mask = np.dstack([mask, mask, mask]) / 255
out = img * mask
p=cv2.bitwise_not(out) 
plt.imshow(p)
cv2.imshow('Output', out)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imwrite('output.png', out)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# True

# %%
#th, im_th = cv2.threshold(out, 100, 255, cv2.THRESH_BINARY)
#threshed = cv2.cvtColor(out, cv2.COLOR_GRAY2BGR)
#img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img1 = img + p
#gray_image = cv2.cvtColor(img1, cv2.COLOR_BINARY2GRAY)

# %%
plt.imshow(img1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import cv2
import numpy as np
import time
import json                                                         # this module is used to read json files
import os 
from PIL import Image
import matplotlib.pyplot as plt 
import numpy as np
import cv2


clahefilter = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(16,16))


img = cv2.imread('C:/Users/Jekson/Desktop/Image29.bmp')

# while True:
t1 = time.time() 
# img = img.copy()

# ## crop if required 
# #FACE
x,y,h,w = 550,250,400,300
# # img = img[y:y+h, x:x+w]

#NORMAL
# convert to gray
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
grayimg = gray


GLARE_MIN = np.array([0, 0, 50],np.uint8)
GLARE_MAX = np.array([0, 0, 225],np.uint8)

hsv_img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)

#HSV
frame_threshed = cv2.inRange(hsv_img, GLARE_MIN, GLARE_MAX)


#INPAINT
mask1 = cv2.threshold(grayimg , 220, 255, cv2.THRESH_BINARY)[1]
result1 = cv2.inpaint(img, mask1, 0.1, cv2.INPAINT_TELEA) 



#CLAHE
claheCorrecttedFrame = clahefilter.apply(grayimg)
plt.imshow(claheCorrecttedFrame)

#COLOR 

lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

lab_planes = cv2.split(lab)
print(lab_planes)
lab_planes = np.array(lab_planes)
clahe = cv2.createCLAHE(clipLimit=2.0,tileGridSize=(8,8))
lab_planes[0] = clahe.apply(lab_planes[0])
lab = cv2.merge(lab_planes)
clahe_bgr = cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)


#INPAINT + HSV
result = cv2.inpaint(img, frame_threshed, 0.1, cv2.INPAINT_TELEA) 


#INPAINT + CLAHE
grayimg1 = cv2.cvtColor(clahe_bgr, cv2.COLOR_BGR2GRAY)
mask2 = cv2.threshold(grayimg1 , 220, 255, cv2.THRESH_BINARY)[1]
result2 = cv2.inpaint(img, mask2, 0.1, cv2.INPAINT_TELEA) 



# HSV+ INPAINT + CLAHE
lab1 = cv2.cvtColor(result, cv2.COLOR_BGR2LAB)
lab_planes1 = cv2.split(lab1)
print(lab_planes1)
lab_planes1 = np.array(lab_planes1)
clahe1 = cv2.createCLAHE(clipLimit=2.0,tileGridSize=(8,8))
lab_planes1[0] = clahe1.apply(lab_planes1[0])
lab1 = cv2.merge(lab_planes1)
clahe_bgr1 = cv2.cvtColor(lab1, cv2.COLOR_LAB2BGR)




# fps = 1./(time.time()-t1)
# cv2.putText(clahe_bgr1    , "FPS: {:.2f}".format(fps), (10, 180), cv2.FONT_HERSHEY_SIMPLEX, 0.35, (0, 0, 255))    

# display it
cv2.imshow("IMAGE", img)
cv2.imshow("GRAY", gray)
cv2.imshow("HSV", frame_threshed)
cv2.imshow("CLAHE", clahe_bgr)
cv2.imshow("LAB", lab)
cv2.imshow("HSV + INPAINT", result)
cv2.imshow("INPAINT", result1)
cv2.imshow("CLAHE + INPAINT", result2)  
cv2.imshow("HSV + INPAINT + CLAHE   ", clahe_bgr1)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (array([[58, 58, 60, ..., 41, 43, 42],
#        [58, 58, 56, ..., 42, 42, 42],
#        [60, 61, 59, ..., 42, 42, 42],
#        ...,
#        [69, 69, 72, ..., 65, 64, 59],
#        [71, 66, 67, ..., 47, 48, 48],
#        [74, 73, 71, ..., 37, 36, 40]], dtype=uint8), array([[127, 127, 127, ..., 129, 127, 127],
#        [127, 127, 126, ..., 127, 126, 126],
#        [128, 128, 127, ..., 127, 127, 127],
#        ...,
#        [127, 127, 127, ..., 126, 125, 126],
#        [127, 127, 127, ..., 125, 125, 125],
#        [128, 127, 126, ..., 126, 126, 126]], dtype=uint8), array([[129, 129, 129, ..., 125, 125, 126],
#        [129, 129, 129, ..., 126, 126, 126],
#        [128, 128, 129, ..., 126, 126, 126],
#        ...,
#        [126, 126, 125, ..., 128, 129, 128],
#        [126, 125, 125, ..., 130, 128, 128],
#        [127, 127, 127, ..., 127, 127, 127]], dtype=uint8))
# (array([[58, 58, 60, ..., 41, 43, 42],
#        [58, 58, 56, ..., 42, 42, 42],
#        [59, 61, 59, ..., 42, 42, 42],
# ...

# %%
from colorthief import ColorThief
color_thief = ColorThief('D:/test/blackspot.bmp')
# get the dominant color
dominant_color = color_thief.get_color(quality=1)

print(dominant_color)
# Out:
# [(184, 185, 186), (50, 50, 48), (97, 80, 53)]

# %%
import cv2 
import numpy as np 
  
# video = cv2.VideoCapture("green.mp4")
image = cv2.imread("C:\\Users\\Jekson\\Desktop\\Image29_crop.bmp")
  
# while True:
  
#     ret, frame = video.read()
  
#     frame = cv2.resize(fr, (640, 480))
image = cv2.resize(image, (640, 480))
  
  
u_green = np.array([99, 99, 99])
l_green = np.array([80, 80, 80])
  
mask = cv2.inRange(image, l_green, u_green)
res = cv2.bitwise_and(image, image, mask = mask)
  
f = image - res
f = np.where(f == 0, image, f)
  
#     cv2.imshow("video", frame)
cv2.imshow("mask", f)
  
cv2.waitKey(0)
  
# video.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

img = cv2.imread('C:\\Users\\Jekson\\Desktop\\Image29_crop.bmp')
# print type(img)
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
new=[[[99%j,99%j,99%j] for j in i] for i in img_gray]
dt = np.dtype('f8')
new=np.array(new,dtype=dt)

cv2.imwrite('img.jpg',new)
# Out:
# C:\Users\Jekson\AppData\Local\Temp\ipykernel_13812\2624317479.py:7: RuntimeWarning: divide by zero encountered in remainder
#   new=[[[99%j,99%j,99%j] for j in i] for i in img_gray]
# True

# %%
from PIL import Image
import numpy as np
import cv2
img = Image.open("D:/test/blackspot.bmp")
kernel = np.ones((5, 5), np.uint8)
print(img.mode) #RGB
print(img.size)
width = img.size[0] 
height = img.size[1] 
for i in range(0,width):# process all pixels
    for j in range(0,height):
        data = img.getpixel((i,j))
        #print(data) #(255, 255, 255)
        if (data[0]==0 and data[1]==0 and data[2]==0):
            img.putpixel((i,j),(188, 190, 196))
           

        
img.show()
img.save('D:/test/blackspot1.bmp')
# Out:
# RGB
# (761, 230)

# %%
# subtract the images
star = cv2.imread('D:/test/blackspot1.bmp')
circle = cv2.imread('D:/test/70_image_4381.bmp')
subtracted = cv2.subtract(star, circle)
cv2.imshow('substracted',subtracted)
cv2.waitKey(0)
  
# video.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[79], line 4
#       2 star = cv2.imread('D:/test/blackspot1.bmp')
#       3 circle = cv2.imread('D:/test/70_image_4381.bmp')
# ----> 4 subtracted = cv2.subtract(star, circle)
#       5 cv2.imshow('substracted',subtracted)
#       6 cv2.waitKey(0)
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:650: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'

# %%
# Python program to demonstrate erosion and
# dilation of images.
import cv2
import numpy as np

# Reading the input image
img = cv2.imread('D:/test/blackspot1.bmp')

# Taking a matrix of size 5 as the kernel
kernel = np.ones((2,2), np.uint8)

# The first parameter is the original image,
# kernel is the matrix with which image is
# convolved and third parameter is the number
# of iterations, which will determine how much
# you want to erode/dilate a given image.
# img_erosion = cv2.erode(img, kernel, iterations=1)
img_dilation = cv2.dilate(img, kernel, iterations=2)
img_erosion = cv2.erode(img_dilation, kernel, iterations=1)
cv2.imshow('Input', img)
cv2.imshow('Erosion', img_erosion)
cv2.imshow('Dilation', img_dilation)

cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # black point remove

# %%
from colorthief import ColorThief
from PIL import Image
import numpy as np
import cv2
path = 'D:/test/Image38.bmp'
path1 = 'D:/test/Image38 (2).bmp'
color_thief = ColorThief(path)
# get the dominant color
dominant_color = color_thief.get_color(quality=1)

print(dominant_color)

img = Image.open(path)
img1 = Image.open(path1)
kernel = np.ones((5, 5), np.uint8)
print(img.mode) #RGB
print(img.size)
width = img.size[0] 
height = img.size[1] 
for i in range(0,width):# process all pixels
    for j in range(0,height):
        j1=j
        i1=i
        data = img.getpixel((i,j))
        data1 = img1.getpixel((i1,j1))
#         print(data)
#         print(data1)
        
        #print(data) #(255, 255, 255)
        if (data[0]==0 and data[1]==0 and data[2]==0):
            img.putpixel( (i,j),(data1[1],data1[0],data1[2]))
            print(data1[2],data1[1],data1[0])

        
img.show()
img.save('D:/test/blackspot1.bmp')
# Out:
# (58, 56, 59)
# RGB
# (1050, 490)
# 59 52 59
# 60 53 60
# 59 51 58
# 60 49 57
# 56 48 55
# 62 54 61
# 65 57 64
# 64 56 63
# 59 51 58
# 65 55 61
# 63 55 62
# 63 53 59
# 65 55 61
# 70 60 66
# 64 55 58
# 61 58 60
# 59 60 64
# 59 60 64
# 61 64 68
# 62 63 67
# 58 47 57
# 59 48 58
# 61 50 60
# 64 53 63
# 59 48 58
# 55 47 54
# 55 49 54
# 57 50 57
# 59 52 59
# 60 53 60
# 61 55 60
# 55 48 55
# 57 49 56
# 58 50 57
# 62 53 63
# 65 54 64
# 64 53 63
# 60 52 59
# 60 50 56
# 55 47 54
# 57 49 56
# 64 53 61
# 62 55 60
# 62 54 61
# 62 58 64
# 61 61 67
# 61 59 65
# 63 59 65
# 64 60 66
# 63 59 65
# 65 62 71
# 62 64 72
# 60 61 71
# 61 63 74
# 65 67 78
# 65 66 80
# 61 64 78
# 57 49 56
# 56 48 55
# 56 45 53
# 59 48 56
# 57 49 56
# 61 50 60
# 63 52 62
# 59 48 58
# 56 45 55
# 56 45 55
# 55 47 54
# 53 47 52
# 55 48 55
# 55 48 55
# 52 45 52
# 55 49 54
# 57 50 57
# 55 47 54
# 54 46 53
# 57 48 58
# 58 47 57
# 58 47 57
# 56 48 55
# 59 49 55
# 58 50 57
# 59 51 58
# 61 50 58
# 60 53 58
# 62 54 61
# 58 54 60
# ...

# %% [markdown]
# # make image empty with reflection

# %%
from PIL import Image
from PIL import Image
import os.path, sys

path = "D:/test 4/New folder/"
dirs = os.listdir(path)
empty = Image.open('D:/test 4/Image_58_refl.bmp')
empty = empty.convert("RGB")
data = empty.getdata()
for i in dirs:
    if os.path.isfile(path+i):
        im = Image.open(path+i)
        f, e = os.path.splitext(path+i)
       
        
        img = im.convert("RGB")

        datas = img.getdata()
        print(img) 

        new_image_data = []
        for i,item in enumerate(datas):
            # change all white (also shades of whites) pixels to yellow

            if item[0] in list(range(0,35)):
                new_image_data.append((data[i]))
            else:
                new_image_data.append(item)

            # update image data
        img.putdata(new_image_data)

                # save new image
        img.save(f+ '_edit' + '.bmp')

# show image in preview
plt.imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1050x490 at 0x1A332679E50>
# <PIL.Image.Image image mode=RGB size=1050x490 at 0x1A33329E0D0>
# <PIL.Image.Image image mode=RGB size=1050x490 at 0x1A33329E160>
# <PIL.Image.Image image mode=RGB size=1050x490 at 0x1A33329E190>
# <PIL.Image.Image image mode=RGB size=1050x490 at 0x1A33329E100>
# <PIL.Image.Image image mode=RGB size=1050x490 at 0x1A33329E070>

# %% [markdown]
# # difference

# %%
import cv2
img1 = cv2.imread('D:/test 3/Image_1_edit.bmp',cv2.IMREAD_UNCHANGED)
img2 = cv2.imread('D:/test/Image_empty_1.bmp',cv2.IMREAD_UNCHANGED)

#--- take the absolute difference of the images ---
difference = cv2.subtract(img1, img2)
cv2.imshow('diff',difference)
cv2.waitKey(0)
print(difference)
cv2.imwrite('D:/test/diff.bmp',difference)
# Out:
# [[[ 0  0  6]
#   [ 0  0  6]
#   [ 0  0  6]
#   ...
#   [ 0  0  8]
#   [ 0  0  8]
#   [ 0  0  8]]
#
#  [[ 0  0  6]
#   [ 0  0  6]
#   [ 0  0  6]
#   ...
#   [ 0  0  8]
#   [ 0  0  8]
#   [ 0  0  8]]
#
#  [[ 0  0  6]
#   [ 0  0  6]
#   [ 0  0  6]
#   ...
#   [ 0  0  8]
#   [ 0  0  8]
#   [ 0  0  8]]
#
#  ...
#
#  [[ 8  6  7]
#   [ 8  6  7]
#   [ 9  6  7]
#   ...
#   [11  6  8]
#   [ 9  6  5]
#   [ 6  6  6]]
#
#  [[ 8  6  7]
#   [ 8  6  7]
#   [ 9  6  7]
#   ...
#   [ 0  7  8]
#   [ 0  6  7]
#   [ 2  6  7]]
#
#  [[ 8  6  7]
#   [ 9  6  7]
#   [ 9  6  7]
#   ...
#   [ 1  7  9]
#   [ 1  7  8]
#   [ 2  6  7]]]
# True

# %%
import cv2

# load images
image1 = cv2.imread('test_image_altered_background_2.bmp')
image2 = cv2.imread('test_image_altered_background_1.bmp')

# compute difference
difference = cv2.subtract(image1, image2)

# color the mask red
Conv_hsv_Gray = cv2.cvtColor(difference, cv2.COLOR_BGR2GRAY)
ret, mask = cv2.threshold(Conv_hsv_Gray, 0, 255,cv2.THRESH_BINARY_INV |cv2.THRESH_OTSU)
difference[mask != 255] = [0, 0, 255]

# add the red mask to the images to make the differences obvious
image1[mask != 255] = [0, 0, 255]
image2[mask != 255] = [0, 0, 255]

# store images
cv2.imwrite('diffOverImage1.png', image1)
cv2.imwrite('diffOverImage2.png', image1)
cv2.imwrite('diff.png', difference)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 11
#       8 difference = cv2.subtract(image1, image2)
#      10 # color the mask red
# ---> 11 Conv_hsv_Gray = cv2.cvtColor(difference, cv2.COLOR_BGR2GRAY)
#      12 ret, mask = cv2.threshold(Conv_hsv_Gray, 0, 255,cv2.THRESH_BINARY_INV |cv2.THRESH_OTSU)
#      13 difference[mask != 255] = [0, 0, 255]
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
# Out:
# -1

# %%
# Importing Image and ImageFilter module from PIL package
from PIL import Image, ImageFilter

# creating a image object
im1 = Image.open(r"D:/test/Image38 (2).bmp")

# applying the Gaussian Blur filter
im2 = im1.filter(ImageFilter.GaussianBlur(radius = 5))

im2.show()

# %%
from skimage.metrics import structural_similarity
import cv2
import numpy as np

# Load images
before = cv2.imread('D:/test 4/New folder/Image_1_refl_edit.bmp')
after =  cv2.imread('D:/test 4/Image_58_refl.bmp')

# Convert images to grayscale
before_gray = cv2.cvtColor(before, cv2.COLOR_BGR2GRAY)
after_gray = cv2.cvtColor(after, cv2.COLOR_BGR2GRAY)

# Compute SSIM between the two images
(score, diff) = structural_similarity(before_gray, after_gray, full=True)
print("Image Similarity: {:.4f}%".format(score * 100))

# The diff image contains the actual image differences between the two images
# and is represented as a floating point data type in the range [0,1] 
# so we must convert the array to 8-bit unsigned integers in the range
# [0,255] before we can use it with OpenCV
diff = (diff * 255).astype("uint8")
diff_box = cv2.merge([diff, diff, diff])

# Threshold the difference image, followed by finding contours to
# obtain the regions of the two input images that differ
thresh = cv2.threshold(diff, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)[1]
contours = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
contours = contours[0] if len(contours) == 2 else contours[1]

mask = np.zeros(before.shape, dtype='uint8')
filled_after = after.copy()

for c in contours:
    area = cv2.contourArea(c)
    if area > 40:
        x,y,w,h = cv2.boundingRect(c)
        cv2.rectangle(before, (x, y), (x + w, y + h), (36,255,12), 2)
        cv2.rectangle(after, (x, y), (x + w, y + h), (36,255,12), 2)
        cv2.rectangle(diff_box, (x, y), (x + w, y + h), (36,255,12), 2)
        cv2.drawContours(mask, [c], 0, (255,255,255), -1)
        cv2.drawContours(filled_after, [c], 0, (0,255,0), -1)

cv2.imshow('before', before)
cv2.imshow('after', after)
cv2.imshow('diff', diff)
cv2.imshow('diff_box', diff_box)
cv2.imshow('mask', mask)
cv2.imshow('filled after', filled_after)
cv2.waitKey()
# Out:
# Image Similarity: 93.3035%
# -1

# %%
# pip install scikit-image

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt 
img = cv2.imread("D:/test/Image38 (3).bmp", 0)
equ = cv2.equalizeHist(img)

plt.hist(img.flat, bins=100, range=(0, 255))

plt.hist(equ.flat, bins=100, range=(0, 255))
clahe = cv2.createCLAHE(clipLimit =2.0, tileGridSize=(8,8))
cl_img = clahe.apply(img)

plt.hist(cl_img.flat, bins=100, range=(100, 255))
ret, thresh1 = cv2.threshold(cl_img, 190, 150, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(cl_img, 190, 255, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(cl_img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

cv2.imshow('before', thresh3)
# cv2.imshow('after', after)
# cv2.imshow('diff', diff)
# cv2.imshow('diff_box', diff_box)
cv2.waitKey()
# Out:
# -1

# %%
import cv2, numpy as np
bgr = cv2.imread('C:/Users/Jekson/Desktop/Image29.bmp')
lab = cv2.cvtColor(bgr, cv2.COLOR_BGR2LAB)
lab_planes = cv2.split(lab)
clahe = cv2.createCLAHE(clipLimit=2.0,tileGridSize=(100,100))
print(lab_planes[0])
lab_planes = np.array(lab_planes)
lab_planes[0] = clahe.apply(lab_planes[0])
lab = cv2.merge(lab_planes)
bgr = cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)
cv2.imwrite('_example111.jpg', bgr)
# Out:
# [[58 58 60 ... 41 43 42]
#  [58 58 56 ... 42 42 42]
#  [60 61 59 ... 42 42 42]
#  ...
#  [69 69 72 ... 65 64 59]
#  [71 66 67 ... 47 48 48]
#  [74 73 71 ... 37 36 40]]
# True

# %%
with open("D:/test/New folder/70_color_image57_flip.txt", "r+") as file:
    x=[]
    y=[] 
    
    for  i,line in enumerate(file):
        
#         data =file.read()
#         print (line.split(" ")[1])
        x.append(line.split(" ")[1])
        y.append("%.6f" % (1-float(x[i])))
#     data =file.read()   
#     for i,line in enumerate(file):
#         print (line.split(" ")[1])
#         data.replace(line.split(" ")[1],str(y[i]))
#     file.write(data)
        
        
print(y)
# Out:
# ['0.864286', '0.667857', '0.487857', '0.313571', '0.120714', '0.860714', '0.668571', '0.492857', '0.307857', '0.122857']

# %%
with open("D:/test/New folder/70_color_image57_flip.txt", 'r') as f:
    for line in f:
        words = line.split()
        for i in words:
            for letter in i:
                if(letter.isdigit()):
                    print(letter)
# Out:
# 0
# 0
# 1
# 3
# 5
# 7
# 1
# 4
# 0
# 2
# 6
# 0
# 7
# 1
# 4
# 0
# 0
# 7
# 7
# 1
# 4
# 3
# 0
# 1
# 5
# 4
# 7
# 6
# 2
# 0
# 0
# 3
# 3
# 2
# 1
# 4
# 3
# 0
# 2
# 7
# 3
# 8
# 1
# 0
# 0
# 0
# 7
# 0
# 0
# 0
# 0
# 0
# 1
# 6
# 6
# 6
# 6
# 7
# 0
# 0
# 5
# 1
# 2
# 1
# 4
# 3
# 0
# 2
# 4
# 1
# 6
# 6
# 7
# 0
# 0
# 5
# 2
# 8
# 5
# 7
# 0
# 1
# 6
# 9
# 0
# 4
# 8
# 0
# 0
# 6
# 8
# 6
# 4
# 2
# 9
# 0
# 2
# 9
# 1
# 6
# 6
# 7
# 0
# 0
# 6
# 7
# 1
# 4
# 3
# 0
# 1
# 6
# 9
# 0
# 4
# 8
# 0
# 0
# 8
# 7
# 9
# 2
# 8
# 6
# 0
# 2
# 4
# 8
# 8
# 1
# 0
# 0
# 0
# 5
# 5
# 7
# 1
# 4
# 0
# 1
# 6
# 9
# 0
# 4
# 8
# 0
# 0
# 1
# 3
# 9
# 2
# 8
# 6
# 0
# 6
# 9
# 8
# 8
# 1
# 0
# 0
# 0
# 5
# 2
# 8
# 5
# 7
# 0
# 1
# 6
# 9
# 0
# 4
# 8
# 0
# 0
# 3
# 3
# 1
# 4
# 2
# 9
# 0
# 7
# 0
# 8
# 3
# 3
# 3
# 0
# 0
# 6
# 2
# 8
# 5
# 7
# 0
# 1
# 6
# 9
# 0
# 4
# 8
# 0
# 0
# 5
# 0
# 7
# 1
# 4
# 3
# 0
# 6
# 7
# 3
# 8
# 1
# 0
# 0
# 0
# 6
# 2
# 8
# 5
# 7
# 0
# 1
# 6
# 6
# 6
# 6
# 7
# 0
# 0
# 6
# 9
# 2
# 1
# 4
# 3
# 0
# 6
# 9
# 8
# 8
# 1
# 0
# 0
# 0
# 5
# ...

# %%
# creating a variable and storing the text
# that we want to search
search_text = "dummy"

# creating a variable and storing the text
# that we want to add
replace_text = "replaced"

# Opening our text file in read only
# mode using the open() function
with open(r'SampleFile.txt', 'r') as file:

	# Reading the content of the file
	# using the read() function and storing
	# them in a new variable
	data = file.read()

	# Searching and replacing the text
	# using the replace() function
	data = data.replace(search_text, replace_text)

# Opening our text file in write only
# mode to write the replaced content
with open(r'SampleFile.txt', 'w') as file:

	# Writing the replaced data in our
	# text file
	file.write(data)

# Printing Text replaced
print("Text replaced")

# %% [markdown]
# # reflection removal project

# %%
from frr import FastReflectionRemoval

path = "D:/test 4/New folder/"
dirs = os.listdir(path)

for i in dirs:
    if os.path.isfile(path+i):
#         im = Image.open(path+i)
        f, e = os.path.splitext(path+i)

# numpy array with values between 0 and 1 of shape (H, W, C)
        img = cv2.imread(path+i)
        img = np.array(img/255)
        # instantiate the algoroithm class
        alg = FastReflectionRemoval(h = 0.040)
        # run the algorithm and get result of shape (H, W, C)
        dereflected_img = alg.remove_reflection(img)

        cv2.imwrite(f+'_refl'+'.bmp',dereflected_img*255)
#         cv2.imshow('diff',dereflected_img)
#         cv2.waitKey(0)

# %%
from PIL import Image
from PIL import Image
import os.path, sys

path = "D:/test 4/New folder/"  #folder of the images
dirs = os.listdir(path)
empty = Image.open('D:/test 4/Image_58_refl.bmp') #empty image
empty = empty.convert("RGB")
data = empty.getdata()
for i in dirs:
    if os.path.isfile(path+i):
        im = Image.open(path+i)
        f, e = os.path.splitext(path+i)
       
        
        img = im.convert("RGB")

        datas = img.getdata()
        print(img) 

        new_image_data = []
        for i,item in enumerate(datas):
            # change all white (also shades of whites) pixels to yellow

            if item[0] in list(range(0,35)):
                new_image_data.append((data[i]))
            else:
                new_image_data.append(item)

            # update image data
        img.putdata(new_image_data)

                # save new image
        img.save(f+ '_edit' + '.bmp')

# show image in preview
plt.imshow(img)

# %%
from skimage.metrics import structural_similarity
import cv2
import numpy as np
import os.path, sys
# Load images

after =  cv2.imread('D:/test 4/Image_58_refl.bmp') #empty image
after_gray = cv2.cvtColor(after, cv2.COLOR_BGR2GRAY)
# Convert images to grayscale
path = "D:/test 4/New folder/" #folder of the images
dirs = os.listdir(path)

for i in dirs:
    if os.path.isfile(path+i):
#         im = Image.open(path+i)
        f, e = os.path.splitext(path+i)

        print(f)
        before = cv2.imread(path+i)
        before_gray = cv2.cvtColor(before, cv2.COLOR_BGR2GRAY)

        # Compute SSIM between the two images
        (score, diff) = structural_similarity(before_gray, after_gray, full=True)
        print("Image Similarity: {:.4f}%".format(score * 100))

        # The diff image contains the actual image differences between the two images
        # and is represented as a floating point data type in the range [0,1] 
        # so we must convert the array to 8-bit unsigned integers in the range
        # [0,255] before we can use it with OpenCV
        diff = (diff * 255).astype("uint8")
        diff_box = cv2.merge([diff, diff, diff])

        # Threshold the difference image, followed by finding contours to
        # obtain the regions of the two input images that differ
        thresh = cv2.threshold(diff, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)[1]
        contours = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        contours = contours[0] if len(contours) == 2 else contours[1]

        mask = np.zeros(before.shape, dtype='uint8')
        filled_after = after.copy()

        for c in contours:
            area = cv2.contourArea(c)
            if area > 40:
                x,y,w,h = cv2.boundingRect(c)
                cv2.rectangle(before, (x, y), (x + w, y + h), (36,255,12), 2)
                cv2.rectangle(after, (x, y), (x + w, y + h), (36,255,12), 2)
                cv2.rectangle(diff_box, (x, y), (x + w, y + h), (36,255,12), 2)
                cv2.drawContours(mask, [c], 0, (255,255,255), -1)
                cv2.drawContours(filled_after, [c], 0, (0,255,0), -1)
        print(f)
        cv2.imshow('before', before)
        cv2.imshow('after', after)
        cv2.imshow('diff', diff)
        cv2.imshow('diff_box', diff_box)
        cv2.imshow('mask', mask)
        cv2.imshow('filled after', filled_after)
        cv2.waitKey()
# Out:
# D:/test 4/New folder/Image_1_refl
# Image Similarity: 92.8180%
# D:/test 4/New folder/Image_1_refl
# D:/test 4/New folder/Image_1_refl_edit
# Image Similarity: 93.3035%
# D:/test 4/New folder/Image_1_refl_edit
# D:/test 4/New folder/Image_1_refl_edit_refl
# Image Similarity: 93.2267%
# D:/test 4/New folder/Image_1_refl_edit_refl
# D:/test 4/New folder/Image_1_refl_refl
# Image Similarity: 92.7625%
# D:/test 4/New folder/Image_1_refl_refl

# %% [markdown]
# # labelme JSON to Labelimg Yolo

# %%
import json                                                         # this module is used to read json files
import os 
import numpy as np
# a= str(null)
def convert(size, box):
    dw = 1./size[0]
    dh = 1./size[1]
    x = (box[0] + box[1])/2.0
    y = (box[2] + box[3])/2.0
    w = box[1] - box[0]
    h = box[3] - box[2]
    x = x*dw
    w = w*dw
    y = y*dh
    h = h*dh
    return (x,y,w,h)
folder_path = "D:/test 6/json/"
o = folder_path.split("/")
z= len(o)-2
o = o[:z]
path = "/".join(o)+"/yolo"


files = os.listdir(folder_path)
if(os.path.exists(path) == False):
    os.mkdir(path)
for index,file in enumerate(files): 
    g=file.split(".")# for each file in the folder
    txt_outfile = open(path+"/"+g[0]+".txt","a")
    txt_outfile.close()

for index,file in enumerate(files):   
    g=file.split(".")# for each file in the folder
    txt_outfile = open(path+"/"+g[0]+".txt","a")
#     print(txt_outfile)
    with open(f"{folder_path}/{file}", "r+") as f:
#         print(file)# you open the file
        data = json.load(f)
        
        
        n = len(data['shapes'])
        coordinates=[]     #array for all the coordinates
        k=[]
        a=data['imageHeight']
        b=data['imageWidth']
        
        for item in data["shapes"]:
            
            label = item["label"]
#             print(label)
            point = item["points"]
#             print(point)
#             print(len(point))
            x1=[]
            y1=[]
            for i in range(len(point)):
#                 print(point[i][0])
                    x1.append(point[i][0])
#                     print(x1)
                    y1.append(point[i][1])

#                     x2 = point[1][0]
#                     y2 = point[1][1]

                    xmin = min(x1)
                   
                    xmax = max(x1)
                    ymin = min(y1)
                    ymax = max(y1)

            print(xmin)
            height =data["imageHeight"]
            width = data["imageWidth"]
            b = (xmin, xmax, ymin, ymax)
            bb = convert((width,height), b)
            print(bb)
        

            txt_outfile.write("0"+" "+" ".join([str(a) for a in bb]) + '\n')
            txt_outfile.seek(0)
# Out:
# 730.6996677841889
# (0.9292683311071733, 0.2882507029312968, 0.09781457116810816, 0.26351153958515927)
# 597.0798424235699
# (0.768850748432751, 0.27558833553950896, 0.09895488861593604, 0.26481876332622595)
# 462.94121353411884
# (0.6031964794468657, 0.28275380973383624, 0.09087196242597508, 0.2736077481840194)
# 183.5354838709677
# (0.266351976822245, 0.28198341013824885, 0.09044977564215814, 0.27817343946376205)
# 55.19127572016464
# (0.1122753400433008, 0.2705258867332941, 0.09155965425487954, 0.27865961199294526)
# 730.1858736059479
# (0.9278415112112904, 0.713037666825261, 0.09619898963716401, 0.27009561399648097)
# 182.03999999999996
# (0.2648976514853099, 0.7067227141278313, 0.09114470056098135, 0.2793156604864859)
# 50.13148846960178
# (0.10836836654795289, 0.6978736075500915, 0.09593796569927497, 0.2698796192813681)
# 327.48
# (0.4418795180722892, 0.28080000000000005, 0.09465060240963856, 0.2729142857142857)
# 324.44
# ...
